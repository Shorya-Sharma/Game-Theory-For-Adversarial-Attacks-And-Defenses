# %% [markdown]
# # Basic Configs

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import datasets, transforms
from torch.utils import data

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Global Variables

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")
cpu = torch.device("cpu")
batch_size = 128
num_workers = 4

# %% [markdown]
# ## Load Repo
# - Rename the folder to `project`

# %%
# !rm -rf project

# %%
# !git clone https://github.com/effie-0/IDL-Project.git
# Out:
# Cloning into 'IDL-Project'...
# remote: Enumerating objects: 240, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 240 (delta 123), reused 130 (delta 52), pack-reused 0
# Receiving objects: 100% (240/240), 1.60 MiB | 3.51 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %%
# !mv IDL-Project project

# %%
# !cd project; git checkout attack
# Out:
# Branch 'attack' set up to track remote branch 'attack' from 'origin'.
# Switched to a new branch 'attack'

# %% [markdown]
# # Load Functions

# %%
from project.summarize.load_data import AdvDataset, get_data

# %% [markdown]
# ## Load Dataset

# %%
trainset, trainloader, testset, testloader = get_data(batch_size)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Load Models

# %%
from project.summarize.classifier import ResidualBlock, ResNet18, cifar_resnet20, ResNet50, VGG

# %%
resnet18 = ResNet18(ResidualBlock)
resnet20 = cifar_resnet20('cifar10')  # With pretrained model
resnet50 = ResNet50()
vgg16 = VGG('VGG16')
# Out:
# Downloading: "https://github.com/chenyaofo/CIFAR-pretrained-models/releases/download/resnet/cifar10-resnet20-30abc31d.pth" to /root/.cache/torch/hub/checkpoints/cifar10-resnet20-30abc31d.pth
# HBox(children=(FloatProgress(value=0.0, max=1117131.0), HTML(value='')))

# %% [markdown]
# ### Load Trained Models

# %%
vgg16_path = "/content/gdrive/My Drive/18-786 IDL/IDL.dll/models/vgg16.pth"
vgg16.load_state_dict(torch.load(vgg16_path)['model_state_dict'])

resnet18_path = "/content/gdrive/My Drive/18-786 IDL/IDL.dll/models/ResNet18.pth"
resnet18.load_state_dict(torch.load(resnet18_path)['model_state_dict'])

resnet50_path = "/content/gdrive/My Drive/18-786 IDL/IDL.dll/models/Copy of ResNet50_49.pth"
resnet50.load_state_dict(torch.load(resnet50_path)['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
models = {
    'vgg16': vgg16,
    'resnet18': resnet18,
    'resnet20': resnet20,
    'resnet50': resnet50,
}

# %% [markdown]
# # Generate the Adversarial Samples

# %%
from project.summarize.generate_attack import generate_mi_fgsm_attack

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## Evaluate the models

# %%
from project.summarize.normal_train import evaluate

# %% [markdown]
# ## Eps = 0.03

# %%
other_samples = {}
eps = 0.03

for model_name, model in models.items():
    model.to(device)
    model.eval()
    acc, adv_ex, adv_label = generate_mi_fgsm_attack(model, criterion, testloader, testset, eps, device)
    model.to(cpu)
    torch.cuda.empty_cache()
    dataset = AdvDataset(adv_ex, adv_label)
    loader = data.DataLoader(dataset, batch_size=batch_size, 
                             shuffle=False,
                             num_workers=num_workers)
    other_samples[model_name] = (dataset, loader)
# Out:
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# Epsilon: 0.03	Test Accuracy = 2318 / 10000 = 0.2318
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# decay_rate =  0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-51a732191f86> in <module>()
#       5     model.to(device)
#       6     model.eval()
# ----> 7     acc, adv_ex, adv_label = generate_mi_fgsm_attack(model, criterion, testloader, testset, eps, device)
#       8     model.to(cpu)
#       9     torch.cuda.empty_cache()
#
# /content/project/summarize/generate_attack.py in generate_mi_fgsm_attack(model, criterion, test_loader, test_dataset, epsilon, device)
#      53
#      54 def generate_mi_fgsm_attack(model, criterion, test_loader, test_dataset, epsilon, device):
# ---> 55     return generate_attack(model, criterion, mi_fgsm_attack, test_loader, test_dataset, epsilon, device)
#      56
#      57
#
# /content/project/summarize/generate_attack.py in generate_attack(model, criterion, attack, test_loader, test_dataset, epsilon, device)
#      21
#      22         # Call Attack
# ---> 23         perturbed_data = attack(data, epsilon, data_grad, mask, model, criterion, data, target)
#      24
#      25         # Re-classify the perturbed image
#
# /content/project/summarize/attack.py in mi_fgsm_attack(image, epsilon, data_grad, mask, model, criterion, data, target, decay_rate)
#      56     for t in range(int(rounds)):
#      57         if t != 0:
# ---> 58             data_grad, mask = get_grad(model, criterion, x, target)
#      59         grad = decay_rate * grad + data_grad / torch.norm(data_grad, p=1)
#      60         if mask is None:
#
# /content/project/summarize/attack.py in get_grad(model, criterion, data, target)
#       7
#       8     # Forward pass the data through the model
# ----> 9     output = model(data)
#      10     init_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
#      11
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /content/project/summarize/classifier.py in forward(self, x)
#     107         out = self.layer1(out)
#     108         out = self.layer2(out)
# --> 109         out = self.layer3(out)
#     110         out = self.layer4(out)
#     111         out = F.avg_pool2d(out, 4)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /content/project/summarize/classifier.py in forward(self, x)
#      26
#      27     def forward(self, x):
# ---> 28         out = self.left(x)
#      29         out += self.shortcut(x)
#      30         out = F.relu(out)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# KeyboardInterrupt:

# %% [markdown]
# # 4x4 Matrix

# %%
matrix = {}
for model_name, model in models.items():
    line = {}
    matrix[model_name] = line
    model.to(device)
    for adv_name, (dataset, loader) in other_samples.items():
        print('classifier: ', model_name, ';  adversarial data comes from: ', adv_name)
        loss, acc = evaluate(model, loader, criterion, device)
        line[adv_name] = acc
        print('acc = ', acc)
    model.to(cpu)
    torch.cuda.empty_cache()
# Out:
# classifier:  vgg16 ;  adversarial data comes from:  vgg16
# acc =  23.18
# classifier:  vgg16 ;  adversarial data comes from:  resnet18
# acc =  89.92
# classifier:  vgg16 ;  adversarial data comes from:  resnet20
# acc =  91.42
# classifier:  vgg16 ;  adversarial data comes from:  resnet50
# acc =  90.08
# classifier:  resnet18 ;  adversarial data comes from:  vgg16
# acc =  88.82
# classifier:  resnet18 ;  adversarial data comes from:  resnet18
# acc =  37.31
# classifier:  resnet18 ;  adversarial data comes from:  resnet20
# acc =  89.77000000000001
# classifier:  resnet18 ;  adversarial data comes from:  resnet50
# acc =  88.07000000000001
# classifier:  resnet20 ;  adversarial data comes from:  vgg16
# acc =  88.86
# classifier:  resnet20 ;  adversarial data comes from:  resnet18
# acc =  88.06
# classifier:  resnet20 ;  adversarial data comes from:  resnet20
# acc =  10.02
# classifier:  resnet20 ;  adversarial data comes from:  resnet50
# acc =  86.77
# classifier:  resnet50 ;  adversarial data comes from:  vgg16
# acc =  88.58
# classifier:  resnet50 ;  adversarial data comes from:  resnet18
# acc =  87.33
# classifier:  resnet50 ;  adversarial data comes from:  resnet20
# acc =  89.05999999999999
# classifier:  resnet50 ;  adversarial data comes from:  resnet50
# acc =  26.14
